# %% [markdown]
# # 运用文本相似度实现（证券）智能客服

# %% [markdown]
# ## 总接口

# %%
# 导入数据以及模型

import pandas as pd

data = pd.read_csv("data_service_competition.csv")
# Out:
#                              客户提问               知识库标准问
# 0                自助开户的第三方存管要怎么补办？       自助开户后如何补办三方存管？
# 1                        自助开户三方存管       自助开户后如何补办三方存管？
# 2             手机App里开户后，如何绑定第三方存管       自助开户后如何补办三方存管？
# 3                  自助开户后如何补办三方存管？       自助开户后如何补办三方存管？
# 4             我的帐户怎么不能进行和银行间的转账了？             转账失败的原因？
# 5                         转账失败的原因             转账失败的原因？
# 6                        转账失败的原因？             转账失败的原因？
# 7                什么原因银行转账到帐户，转入失败             转账失败的原因？
# 8               我刚才为何银行资金转账到证券失败？             转账失败的原因？
# 9                     登录不成功，是什么原因             转账失败的原因？
# 10                      不允许取款的原因?             转账失败的原因？
# 11                        转账失败为什么             转账失败的原因？
# 12    我能在金融终端查到我的银行余额信息的，但转账为何不成功             转账失败的原因？
# 13                  貌似我现在无法银证转账呢？             转账失败的原因？
# 14                        转帐失败的原因             转账失败的原因？
# 15           你好 我银证转账从银行转证券怎么转不成功             转账失败的原因？
# 16           我要从银行转账到证券帐户上为什么转不了？             转账失败的原因？
# 17         你好，请问为何我的邮政储蓄银行转账不到帐户？             转账失败的原因？
# 18                   证券转银行卡为什么转不了         证券转银行为什么转不了？
# 19                     为什么银行转证券不行         证券转银行为什么转不了？
# 20                      银转证为什么转不了         证券转银行为什么转不了？
# 21                      为什么转银行转不了         证券转银行为什么转不了？
# 22                  你好！证券转银行怎么转不了         证券转银行为什么转不了？
# 23                  我的钱怎么转不了银行“呢？         证券转银行为什么转不了？
# 24                  我的钱为什么不能转到银行？         证券转银行为什么转不了？
# 25                   为什么我的资金不能转银行         证券转银行为什么转不了？
# 26                      钱为什么转不了银行         证券转银行为什么转不了？
# 27             我的资金怎么从证劵转银行，转不出来？         证券转银行为什么转不了？
# 28                      请问银行无法转证券         证券转银行为什么转不了？
# 29                     怎么了，银行转不了钱         证券转银行为什么转不了？
# ...                           ...                  ...
# 1287                      B股最后交易日             B股的交易时间？
# 1288                   B股交收规则是什么？             B股的交收规则？
# 1289                     B股资金交收时间             B股的交收规则？
# 1290       如果我销户是不是就必须把账户里的股票卖完啊？       A股账户销户有哪些注意事项？
# 1291            我今天把股票卖了，可以今天销户吗？       A股账户销户有哪些注意事项？
# 1292              那我现在账户里有股票，能销户吗       A股账户销户有哪些注意事项？
# 1293                 明天卖股票后能当天销户吗       A股账户销户有哪些注意事项？
# 1294  对，比如说今天我申购新股，没有其他交易，可以去办销户吗       A股账户销户有哪些注意事项？
# 1295            您好，请问从其他证券公司转户怎么转            A股账户如何转户？
# 1296     002399停牌好久了，什么原因？啥时候复牌呢？           A股停牌原因有哪些？
# 1297                  积成电子停牌原因是什么           A股停牌原因有哪些？
# 1298                    A股开户需要收费吗            A股开户是否收费？
# 1299                 请问A股开户收费不收啊？            A股开户是否收费？
# 1300                   请问A股开户免费么？            A股开户是否收费？
# 1301                  沪深A股也没有开户费吗            A股开户是否收费？
# 1302      网上开户上A股和深A股都要各收20元手续费吗？            A股开户是否收费？
# 1303             如何区分港股通和A股的退市制度？        A股和港股通退市制度的区别
# 1304         请问，要怎么区分港股通和A股的退市制度？        A股和港股通退市制度的区别
# 1305            港股通和A股退市制度的区别是什么？        A股和港股通退市制度的区别
# 1306           A股和港股通的退市制度有什么不一样？        A股和港股通退市制度的区别
# 1307             港股和A股的显示颜色有什么不同？     A股和港股的显示颜色有什么区别？
# 1308           A股和港股的显示颜色有什么不一样？？     A股和港股的显示颜色有什么区别？
# 1309              怎样区别A股和港股的显示颜色？     A股和港股的显示颜色有什么区别？
# 1310              如何区分A股和港股的显示颜色？     A股和港股的显示颜色有什么区别？
# 1311        A股股票配股与增发的缴款时间有什么不一样？  A股股票配股与增发的缴款时间有何区别？
# 1312          怎样区分A股股票配股与增发的缴款时间？  A股股票配股与增发的缴款时间有何区别？
# 1313             70岁以上老人能在手机上开户吗？     70岁以上自然人可以手机开户吗?
# 1314               信用账户60岁以上怎么开立？       60岁以上如何开立信用账户？
# 1315           有什么办法开立信用账户在60岁以上？       60岁以上如何开立信用账户？
# 1316             *st股票会在哪些情况下退市呢？       *st股票在什么情况下退市？
#
# [1317 rows x 2 columns]

# %%
#textCNN模型
class textCNN(nn.Module):
    def __init__(self,args):
        super(textCNN, self).__init__()
        vocb_size = args['vocb_size']
        dim = args['dim']
        n_class = args['n_class']
        max_len = args['max_len']
        embedding_matrix=args['embedding_matrix']
        #需要将事先训练好的词向量载入
        self.embeding = nn.Embedding(vocb_size, dim,_weight=embedding_matrix)
        self.conv1 = nn.Sequential(
                     nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5,
                               stride=1, padding=2),

                     nn.ReLU(),
                     nn.MaxPool2d(kernel_size=2) # (16,64,64)
                     )
        self.conv2 = nn.Sequential(
                     nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2),
                     nn.ReLU(),
                     nn.MaxPool2d(2)
                     )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.conv4 = nn.Sequential(  # (16,64,64)
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.out = nn.Linear(512, n_class)

    def forward(self, x):
        x = self.embeding(x)
        x=x.view(x.size(0),1,max_len,word_dim)
        #print(x.size())
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(x.size(0), -1) # 将（batch，outchanel,w,h）展平为（batch，outchanel*w*h）
        #print(x.size())
        output = self.out(x)
return output
